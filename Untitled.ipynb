# %% [markdown]
# ## Objective
#
# 1. Which generation introduce the strongest pokemon? (distribution of attack of each generation)
# 2. Are pokemon in general geared towards offense or defense? (heatmap of attack and defense)
# 3. Which type has the most pokemon? bar chart of type
# 4. How is the trend in number of pokemon species accross generation? line plot of count of pokemon each generation
# 5. Top 6 strongest pokemon with highest status combined (dream team candidate)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/pokemon.csv')

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %%
df['experience_growth']
# Out:
# 0      1059860
# 1      1059860
# 2      1059860
# 3      1059860
# 4      1059860
# 5      1059860
# 6      1059860
# 7      1059860
# 8      1059860
# 9      1000000
# 10     1000000
# 11     1000000
# 12     1000000
# 13     1000000
# 14     1000000
# 15     1059860
# 16     1059860
# 17     1059860
# 18     1000000
# 19     1000000
# 20     1000000
# 21     1000000
# 22     1000000
# 23     1000000
# 24     1000000
# 25     1000000
# 26     1000000
# 27     1000000
# 28     1059860
# 29     1059860
#         ...
# 771    1250000
# 772    1250000
# 773    1059860
# 774    1250000
# 775    1000000
# 776    1000000
# 777    1000000
# 778    1000000
# 779    1000000
# 780    1000000
# 781    1250000
# 782    1250000
# 783    1250000
# 784    1250000
# 785    1250000
# 786    1250000
# 787    1250000
# 788    1250000
# 789    1250000
# 790    1250000
# 791    1250000
# 792    1250000
# 793    1250000
# 794    1250000
# 795    1250000
# 796    1250000
# 797    1250000
# 798    1250000
# ...

# %%
df[df['is_legendary'] == 1][['name','generation','capture_rate']]
# Out:
#            name  generation capture_rate
# 143    Articuno           1            3
# 144      Zapdos           1            3
# 145     Moltres           1            3
# 149      Mewtwo           1            3
# 150         Mew           1           45
# 242      Raikou           2            3
# 243       Entei           2            3
# 244     Suicune           2            3
# 248       Lugia           2            3
# 249       Ho-Oh           2            3
# 250      Celebi           2           45
# 376    Regirock           3            3
# 377      Regice           3            3
# 378   Registeel           3            3
# 379      Latias           3            3
# 380      Latios           3            3
# 381      Kyogre           3            3
# 382     Groudon           3            3
# 383    Rayquaza           3           45
# 384     Jirachi           3            3
# 385      Deoxys           3            3
# 479        Uxie           4            3
# ...

# %%
df[df['height_m'].isnull()][['name']]
# Out:
#           name
# 18     Rattata
# 19    Raticate
# 25      Raichu
# 26   Sandshrew
# 27   Sandslash
# 36      Vulpix
# 37   Ninetales
# 49     Diglett
# 50     Dugtrio
# 51      Meowth
# 52     Persian
# 73     Geodude
# 74    Graveler
# 75       Golem
# 87      Grimer
# 88         Muk
# 102  Exeggutor
# 104    Marowak
# 719      Hoopa
# 744   Lycanroc

# %%
df[df['name'] == 'Rattata']['height_m']
# Out:
# 18   NaN
# Name: height_m, dtype: float64

# %%
df[['height_m','name']].sample(20)
# Out:
#      height_m        name
# 425       1.2    Drifblim
# 25        NaN      Raichu
# 323       0.5     Torkoal
# 659       1.0   Diggersby
# 199       0.7  Misdreavus
# 28        0.4    Nidoran♀
# 54        1.7     Golduck
# 535       0.8   Palpitoad
# 504       1.1     Watchog
# 327       0.7    Trapinch
# 39        1.0  Wigglytuff
# 85        1.1        Seel
# 261       1.0   Mightyena
# 568       1.9    Garbodor
# 131       0.3       Ditto
# 121       1.3    Mr. Mime
# 653       1.0     Braixen
# 263       0.5     Linoone
# 676       0.3      Espurr
# 213       1.5   Heracross
